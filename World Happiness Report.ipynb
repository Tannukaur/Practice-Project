# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
import warnings

# %% [markdown]
# **Data Understanding and Cleaning**

# %%
whr_2012=pd.read_csv('https://raw.github.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
whr_2013=pd.read_csv('https://raw.github.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
whr_2015=pd.read_csv('https://raw.github.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
whr_2016=pd.read_csv('https://raw.github.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
whr_2017=pd.read_csv('https://raw.github.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
whr_2012.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
whr_2013.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
whr_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
whr_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
whr_2017.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
years = [whr_2012, whr_2013, whr_2015, whr_2016, whr_2017]
for year in years:
  print(year.shape)
  print(year.columns)
# Out:
# (158, 12)
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# (158, 12)
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# (158, 12)
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# (158, 12)
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
# ...

# %% [markdown]
# **Features Description**
#
# Happiness Rank: A country's rank on a world scale - determined by how high their happiness score is.
#
# Happiness Score: A score given to a country based on adding up the rankings that a population has given to each category (normalized)
#
# GDP per capita: individuals rank they quality of life based on the amount they earn
#
# Healthy Life Expectancy: ranking healthcare availability and average life expectancy in the country
#
# Freedom: how much an individual is able to conduct them self based on their free will
#
# Trust(Government Corruption): Trust in the government to not be corrupt
#
# Generosity: how much their country is involved in peacekeeping and global aid

# %%
#merging all 5 dataframes into one

whr_all = [whr_2012, whr_2013, whr_2015, whr_2016, whr_2017]
happiness = pd.concat(whr_all)
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# This is used to view basic statistical details like percentile, mean, std etc.

happiness.describe(include='all')
# Out:
#             Country              Region  Happiness Rank  Happiness Score  \
# count           790                 790      790.000000       790.000000
# unique          158                  10             NaN              NaN
# top     Switzerland  Sub-Saharan Africa             NaN              NaN
# freq              5                 200             NaN              NaN
# mean            NaN                 NaN       79.493671         5.375734
# std             NaN                 NaN       45.638235         1.142104
# min             NaN                 NaN        1.000000         2.839000
# 25%             NaN                 NaN       40.000000         4.518000
# 50%             NaN                 NaN       79.500000         5.232500
# 75%             NaN                 NaN      119.000000         6.269000
# max             NaN                 NaN      158.000000         7.587000
#
#         Standard Error  Economy (GDP per Capita)      Family  \
# ...

# %%
happiness.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# checking for duplicate values

happiness.duplicated().sum()
# Out:
# 632

# %%
# The info() function is used to print a concise summary of a DataFrame

happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 790 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        790 non-null    object
#  1   Region                         790 non-null    object
#  2   Happiness Rank                 790 non-null    int64
#  3   Happiness Score                790 non-null    float64
#  4   Standard Error                 790 non-null    float64
#  5   Economy (GDP per Capita)       790 non-null    float64
#  6   Family                         790 non-null    float64
#  7   Health (Life Expectancy)       790 non-null    float64
#  8   Freedom                        790 non-null    float64
#  9   Trust (Government Corruption)  790 non-null    float64
#  10  Generosity                     790 non-null    float64
#  11  Dystopia Residual              790 non-null    float64
# ...

# %%
#happiness.to_csv('cleaned happiness.csv', index = False)

# %% [markdown]
# **Data Visualization and Analysis**

# %%
# checking the frequency distribution of the variables

happiness.hist(bins='auto', figsize=(15,15));

# %%
happiness[['Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual', 'Standard Error']]
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0                 1            7.587                   1.39651  1.34951
# 1                 2            7.561                   1.30232  1.40223
# 2                 3            7.527                   1.32548  1.36058
# 3                 4            7.522                   1.45900  1.33095
# 4                 5            7.427                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 153             154            3.465                   0.22208  0.77370
# 154             155            3.340                   0.28665  0.35386
# 155             156            3.006                   0.66320  0.47489
# 156             157            2.905                   0.01530  0.41587
# 157             158            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# **Bivariate Plots**

# %%
plt.figure(figsize=(15,10))
sns.heatmap(happiness.corr())
sns.heatmap (happiness.corr(),annot = True, vmin=-1, vmax=1, center=0, cmap='coolwarm', linewidths=4, linecolor='black')
plt.show()

# %%
# happiest countries

happy_countries = happiness[['Country', 'Happiness Rank']].groupby('Country').mean().sort_values(by = 'Happiness Rank', ascending = True)
happy_countries.head()
# Out:
#              Happiness Rank
# Country
# Switzerland             1.0
# Iceland                 2.0
# Denmark                 3.0
# Norway                  4.0
# Canada                  5.0

# %%
# saddest countries 

sad_countries = happiness[['Country', 'Happiness Rank']].groupby('Country').mean().sort_values(by = 'Happiness Rank', ascending = True)
sad_countries.tail()
# Out:
#          Happiness Rank
# Country
# Rwanda            154.0
# Benin             155.0
# Syria             156.0
# Burundi           157.0
# Togo              158.0

# %%
# What countries have the highest GDP per capita over the years?

rich_countries = happiness[['Country', 'Economy (GDP per Capita)']].groupby('Country').mean().sort_values(by = 'Economy (GDP per Capita)', ascending = False)
rich_countries.head()
# Out:
#             Economy (GDP per Capita)
# Country
# Qatar                        1.69042
# Luxembourg                   1.56391
# Kuwait                       1.55422
# Singapore                    1.52186
# Norway                       1.45900

# %% [markdown]
# **Modeling and Prediction**

# %%
new_happiness = happiness.drop(['Country', 'Happiness Rank'], axis=1)
new_happiness.head()
#new_happiness.info()
# Out:
#            Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0  Western Europe            7.587         0.03411                   1.39651
# 1  Western Europe            7.561         0.04884                   1.30232
# 2  Western Europe            7.527         0.03328                   1.32548
# 3  Western Europe            7.522         0.03880                   1.45900
# 4   North America            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
from sklearn.model_selection import train_test_split
x = new_happiness[['Economy (GDP per Capita)', 'Standard Error', 'Health (Life Expectancy)', 'Freedom']]
y = new_happiness['Happiness Score']

#x = features, y = target variable
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)

#print(lm.coef_)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(x_test)

actual_vs_pred = pd.DataFrame({'Actual': y_test, 'Predicted':y_pred})
actual_vs_pred
# Out:
#      Actual  Predicted
# 69    5.548   5.573473
# 35    6.329   6.297026
# 125   4.369   4.715807
# 59    5.791   6.167155
# 48    5.960   6.289181
# ..      ...        ...
# 76    5.286   4.852515
# 64    5.709   5.809650
# 153   3.465   4.626405
# 52    5.878   5.543402
# 116   4.565   4.850752
#
# [158 rows x 2 columns]

# %%
coefficient = lm.coef_

coefficient_df = pd.DataFrame(list(zip(x.columns, lm.coef_)), columns= ['features', 'coefficient'])
coefficient_df
# Out:
#                    features  coefficient
# 0  Economy (GDP per Capita)     1.483966
# 1            Standard Error     2.697434
# 2  Health (Life Expectancy)     0.905569
# 3                   Freedom     2.283669
